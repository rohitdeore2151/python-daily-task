# %% [markdown]
# ##  Pandas Challenges (Based on Your Notebook)

# %% [markdown]
# #### Challenge 1 – Complete Data Cleaning
# #### Your manager gives you a messy dataset.
# #### Perform all of the following:
# #### • Load the dataset.
# #### • Display dataset information.
# #### • Find missing values.
# #### • Remove duplicate rows.
# #### • Fill missing values:
# #### o Age → median
# #### o Balance → mean
# #### #### • Rename:
# #### o Target → CustomerStatus
# #### o AnnualIncome → Income
# #### • Display the first 15 rows.
# #### Methods expected:
# #### read_csv()
# #### info()
# #### isnull()
# #### drop_duplicates()
# #### median()
# #### mean()
# #### fillna()
# #### rename()
# #### head()

# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\rohit\\Downloads\\Task_dataset - Task_dataset.csv")

df
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0          10001  58.0       49184.0      2139          581        NaN
# 1          10002  65.0      162964.0      6197          732    6356.54
# 2          10003  56.0       26956.0     37281          503  143203.92
# 3          10004  55.0       92926.0       925          463  139627.88
# 4          10005  66.0      108236.0      7198          394   75985.46
# ...          ...   ...           ...       ...          ...        ...
# 1015       10450  43.0      173620.0      7121          644   60353.03
# 1016       10753  25.0       54490.0     13794          303  124512.07
# 1017       10810  49.0       82062.0     47170          813   53850.09
# 1018       10267  38.0           NaN     10424          722  138100.05
# 1019       10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target
# 0          2    France    Male        SME   Stay
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    1020 non-null   int64
#  1   Age           970 non-null    float64
#  2   AnnualIncome  967 non-null    float64
#  3   Spending      1020 non-null   int64
#  4   CreditScore   1020 non-null   int64
#  5   Balance       969 non-null    float64
#  6   Tenure        1020 non-null   int64
#  7   Geography     969 non-null    object
#  8   Gender        968 non-null    object
#  9   Segment       969 non-null    object
#  10  Target        1020 non-null   object
# dtypes: float64(3), int64(4), object(4)
# memory usage: 87.8+ KB

# %%
df.isnull().sum()
# Out:
# CustomerID       0
# Age             50
# AnnualIncome    53
# Spending         0
# CreditScore      0
# Balance         51
# Tenure           0
# Geography       51
# Gender          52
# Segment         51
# Target           0
# dtype: int64

# %%
df.drop_duplicates(inplace = True)

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
age_median =  df['Age'].median()
age_median
# Out:
# 44.0

# %%
df["Age"] = df["Age"].fillna(age_median)
df["Age"]
# Out:
# 0      58.0
# 1      65.0
# 2      56.0
# 3      55.0
# 4      66.0
#        ...
# 995    34.0
# 996    47.0
# 997    31.0
# 998    21.0
# 999    63.0
# Name: Age, Length: 1000, dtype: float64

# %%
balance_mean = df["Balance"].mean()
balance_mean
# Out:
# np.float64(97557.56577894738)

# %%
df["Balance"] = df["Balance"].fillna(balance_mean)
df["Balance"]
# Out:
# 0       97557.565779
# 1        6356.540000
# 2      143203.920000
# 3      139627.880000
# 4       75985.460000
#            ...
# 995    181465.650000
# 996     26640.990000
# 997    147220.820000
# 998     94186.480000
# 999    100908.400000
# Name: Balance, Length: 1000, dtype: float64

# %%
df.rename(columns = {"Target":"CustomerStatus","AnnualIncome":"Income"},inplace = True)

# %%
df.head(15)
# Out:
#     CustomerID   Age    Income  Spending  CreditScore        Balance  Tenure  \
# 0        10001  58.0   49184.0      2139          581   97557.565779       2
# 1        10002  65.0  162964.0      6197          732    6356.540000       1
# 2        10003  56.0   26956.0     37281          503  143203.920000       8
# 3        10004  55.0   92926.0       925          463  139627.880000       5
# 4        10005  66.0  108236.0      7198          394   75985.460000       5
# 5        10006  69.0   31390.0     48323          770  107245.620000       6
# 6        10007  58.0  182141.0     24200          891   38457.720000       1
# 7        10008  67.0   95861.0      5729          538  173296.730000       6
# 8        10009  41.0   62638.0     24760          663   41901.410000       4
# 9        10010  22.0  179680.0     42113          475  106827.980000       3
# 10       10011  44.0  187772.0     45599          870   43923.030000       5
# ...

# %% [markdown]
# #### Challenge 2 – Banking Report
# #### The bank wants a numeric report.
# #### Tasks
# #### • Select only numeric columns.
# #### • Display summary statistics.
# #### • Convert Age and CreditScore to float.
# #### • Display information again.

# %%
df.describe()
# Out:
#          CustomerID          Age         Income      Spending  CreditScore  \
# count   1000.000000  1000.000000     950.000000   1000.000000  1000.000000
# mean   10500.500000    44.202000  112458.303158  25285.558000   603.088000
# std      288.819436    15.130834   52409.868404  14211.735656   176.605486
# min    10001.000000    18.000000   20227.000000    537.000000   300.000000
# 25%    10250.750000    31.000000   65922.500000  13213.000000   441.000000
# 50%    10500.500000    44.000000  112347.500000  24901.000000   606.500000
# 75%    10750.250000    57.000000  157973.000000  37960.250000   758.250000
# max    11000.000000    70.000000  199967.000000  49995.000000   900.000000
#
#              Balance       Tenure
# count    1000.000000  1000.000000
# mean    97557.565779     5.241000
# std     54430.062006     3.179155
# min       547.600000     0.000000
# 25%     52074.240000     2.000000
# 50%     97557.565779     5.000000
# 75%    142297.910000     8.000000
# ...

# %%
df["Age"] = df["Age"].astype(float)

df["Age"]
# Out:
# 0      58.0
# 1      65.0
# 2      56.0
# 3      55.0
# 4      66.0
#        ...
# 995    34.0
# 996    47.0
# 997    31.0
# 998    21.0
# 999    63.0
# Name: Age, Length: 1000, dtype: float64

# %%
df["CreditScore"] = df["CreditScore"].astype(float)

df["CreditScore"]
# Out:
# 0      581.0
# 1      732.0
# 2      503.0
# 3      463.0
# 4      394.0
#        ...
# 995    761.0
# 996    780.0
# 997    733.0
# 998    540.0
# 999    559.0
# Name: CreditScore, Length: 1000, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      1000 non-null   int64
#  1   Age             1000 non-null   float64
#  2   Income          950 non-null    float64
#  3   Spending        1000 non-null   int64
#  4   CreditScore     1000 non-null   float64
#  5   Balance         1000 non-null   float64
#  6   Tenure          1000 non-null   int64
#  7   Geography       950 non-null    object
#  8   Gender          950 non-null    object
#  9   Segment         950 non-null    object
#  10  CustomerStatus  1000 non-null   object
# dtypes: float64(4), int64(3), object(4)
# memory usage: 93.8+ KB

# %% [markdown]
# #### Challenge 3 – Duplicate Investigation
# #### Find duplicate customers.
# #### Then
# #### • Count duplicate rows.
# #### • Remove duplicates.
# #### • Print information before and after removing duplicates.
# #### • Show the last 20 rows.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      1000 non-null   int64
#  1   Age             1000 non-null   float64
#  2   Income          950 non-null    float64
#  3   Spending        1000 non-null   int64
#  4   CreditScore     1000 non-null   float64
#  5   Balance         1000 non-null   float64
#  6   Tenure          1000 non-null   int64
#  7   Geography       950 non-null    object
#  8   Gender          950 non-null    object
#  9   Segment         950 non-null    object
#  10  CustomerStatus  1000 non-null   object
# dtypes: float64(4), int64(3), object(4)
# memory usage: 93.8+ KB

# %%
df.drop_duplicates(inplace = True)
df
# Out:
#      CustomerID   Age    Income  Spending  CreditScore        Balance  Tenure  \
# 0         10001  58.0   49184.0      2139        581.0   97557.565779       2
# 1         10002  65.0  162964.0      6197        732.0    6356.540000       1
# 2         10003  56.0   26956.0     37281        503.0  143203.920000       8
# 3         10004  55.0   92926.0       925        463.0  139627.880000       5
# 4         10005  66.0  108236.0      7198        394.0   75985.460000       5
# ..          ...   ...       ...       ...          ...            ...     ...
# 995       10996  34.0   81731.0     40980        761.0  181465.650000       5
# 996       10997  47.0   42475.0      1176        780.0   26640.990000       5
# 997       10998  31.0  120531.0     46929        733.0  147220.820000       4
# 998       10999  21.0   33661.0     22314        540.0   94186.480000       5
# 999       11000  63.0   31930.0       851        559.0  100908.400000       6
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      1000 non-null   int64
#  1   Age             1000 non-null   float64
#  2   Income          950 non-null    float64
#  3   Spending        1000 non-null   int64
#  4   CreditScore     1000 non-null   float64
#  5   Balance         1000 non-null   float64
#  6   Tenure          1000 non-null   int64
#  7   Geography       950 non-null    object
#  8   Gender          950 non-null    object
#  9   Segment         950 non-null    object
#  10  CustomerStatus  1000 non-null   object
# dtypes: float64(4), int64(3), object(4)
# memory usage: 93.8+ KB

# %%
df.tail(20)
# Out:
#      CustomerID   Age    Income  Spending  CreditScore        Balance  Tenure  \
# 980       10981  41.0  199633.0      8498        847.0  173390.590000       7
# 981       10982  34.0   98876.0      6414        541.0   59484.580000       2
# 982       10983  69.0  188933.0     27126        334.0   97557.565779       1
# 983       10984  44.0  107221.0     47514        732.0  175352.250000       1
# 984       10985  50.0   37397.0     23559        730.0  120423.190000       8
# 985       10986  62.0   27169.0      3914        488.0  126031.270000      10
# 986       10987  30.0  184704.0     20524        621.0  115161.870000       1
# 987       10988  63.0  190178.0      9025        720.0  158528.460000       5
# 988       10989  26.0   88335.0     11869        635.0  159905.730000       3
# 989       10990  29.0  123152.0     25228        884.0   44897.430000       0
# 990       10991  58.0   79954.0      6331        773.0   39653.240000       2
# ...

# %% [markdown]
# ####  Challenge 4 – HR Department
# #### HR wants better column names.
# #### Rename
# #### CustomerID → Employee_ID
# #### Age → EmployeeAge
# #### Gender → EmployeeGender
# #### AnnualIncome → Salary
# #### Target → PromotionStatus
# #### Then
# #### • Add prefix
# #### HR_
# #### to every column.
# #### Display 10 random records.

# %%
df.rename(columns = {"CustomerID":"Employee_ID","Age":"EmployeeAge","Gender":"EmployeeGender","AnnualIncome":"Salary","Target":"PromotionStatus"},inplace = True)

df.head(15)
# Out:
#     Employee_ID  EmployeeAge    Income  Spending  CreditScore        Balance  \
# 0         10001         58.0   49184.0      2139        581.0   97557.565779
# 1         10002         65.0  162964.0      6197        732.0    6356.540000
# 2         10003         56.0   26956.0     37281        503.0  143203.920000
# 3         10004         55.0   92926.0       925        463.0  139627.880000
# 4         10005         66.0  108236.0      7198        394.0   75985.460000
# 5         10006         69.0   31390.0     48323        770.0  107245.620000
# 6         10007         58.0  182141.0     24200        891.0   38457.720000
# 7         10008         67.0   95861.0      5729        538.0  173296.730000
# 8         10009         41.0   62638.0     24760        663.0   41901.410000
# 9         10010         22.0  179680.0     42113        475.0  106827.980000
# 10        10011         44.0  187772.0     45599        870.0   43923.030000
# ...

# %%
df = df.add_prefix("HR_")

# %%
df.sample(10)
# Out:
#      HR_HR_Employee_ID  HR_HR_EmployeeAge  HR_HR_Income  HR_HR_Spending  \
# 421              10422               58.0       22515.0           22455
# 622              10623               68.0      177159.0           33959
# 498              10499               34.0      166546.0           12497
# 446              10447               44.0      177722.0           14839
# 650              10651               44.0      180868.0           19277
# 695              10696               33.0      169429.0           41481
# 268              10269               51.0      118782.0           21062
# 820              10821               70.0       60409.0           33002
# 698              10699               46.0      112359.0           21153
# 871              10872               53.0       80215.0            6167
#
#      HR_HR_CreditScore  HR_HR_Balance  HR_HR_Tenure HR_HR_Geography  \
# 421              301.0  151785.830000             6          France
# ...

# %% [markdown]
# #### Challenge 5 – Finance Cleaning
# #### Finance department reports missing values.
# #### Tasks
# #### Fill
# #### AnnualIncome → Median
# #### Balance → Mean
# #### Age → Median
# #### Then
# #### Generate descriptive statistics.

# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\rohit\\Downloads\\Task_dataset - Task_dataset.csv")

df
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0          10001  58.0       49184.0      2139          581        NaN
# 1          10002  65.0      162964.0      6197          732    6356.54
# 2          10003  56.0       26956.0     37281          503  143203.92
# 3          10004  55.0       92926.0       925          463  139627.88
# 4          10005  66.0      108236.0      7198          394   75985.46
# ...          ...   ...           ...       ...          ...        ...
# 1015       10450  43.0      173620.0      7121          644   60353.03
# 1016       10753  25.0       54490.0     13794          303  124512.07
# 1017       10810  49.0       82062.0     47170          813   53850.09
# 1018       10267  38.0           NaN     10424          722  138100.05
# 1019       10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target
# 0          2    France    Male        SME   Stay
# ...

# %%
annuallncome_median =  df['AnnualIncome'].median()
annuallncome_median
# Out:
# 112358.0

# %%
df["Balance"] = df["Balance"].fillna(df["Balance"].mean())
df["Balance"]
# Out:
# 0        97523.535666
# 1         6356.540000
# 2       143203.920000
# 3       139627.880000
# 4        75985.460000
#             ...
# 1015     60353.030000
# 1016    124512.070000
# 1017     53850.090000
# 1018    138100.050000
# 1019     97523.535666
# Name: Balance, Length: 1020, dtype: float64

# %%
age_median = df['Age'].median()
age_median
# Out:
# 44.0

# %%
df.describe()
# Out:
#          CustomerID         Age   AnnualIncome      Spending  CreditScore  \
# count   1020.000000  970.000000     967.000000   1020.000000  1020.000000
# mean   10501.599020   44.249485  112505.928645  25232.615686   602.659804
# std      288.022115   15.521935   52303.362541  14219.393105   176.560690
# min    10001.000000   18.000000   20227.000000    537.000000   300.000000
# 25%    10252.750000   30.250000   66149.000000  13134.750000   440.750000
# 50%    10502.500000   44.000000  112358.000000  24798.000000   607.000000
# 75%    10752.250000   58.000000  158000.500000  37956.000000   757.250000
# max    11000.000000   70.000000  199967.000000  49995.000000   900.000000
#
#              Balance       Tenure
# count    1020.000000  1020.000000
# mean    97523.535666     5.261765
# std     54382.357541     3.185330
# min       547.600000     0.000000
# 25%     52145.757500     2.000000
# 50%     97523.535666     5.000000
# 75%    142086.700000     8.000000
# ...

# %% [markdown]
# #### Challenge 6 – Data Type Audit
# #### The company says
# #### Age and AnnualIncome are stored incorrectly.
# #### Tasks
# #### Convert
# #### Age → int
# #### AnnualIncome → float
# #### Balance → float
# #### Target → string
# #### Print information.

# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\rohit\\Downloads\\Task_dataset - Task_dataset.csv")

df
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0          10001  58.0       49184.0      2139          581        NaN
# 1          10002  65.0      162964.0      6197          732    6356.54
# 2          10003  56.0       26956.0     37281          503  143203.92
# 3          10004  55.0       92926.0       925          463  139627.88
# 4          10005  66.0      108236.0      7198          394   75985.46
# ...          ...   ...           ...       ...          ...        ...
# 1015       10450  43.0      173620.0      7121          644   60353.03
# 1016       10753  25.0       54490.0     13794          303  124512.07
# 1017       10810  49.0       82062.0     47170          813   53850.09
# 1018       10267  38.0           NaN     10424          722  138100.05
# 1019       10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target
# 0          2    France    Male        SME   Stay
# ...

# %%
df.fillna({'Age' : df['Age'].mean()},inplace = True)

df["Age"] = df["Age"].astype(int)

# %%
df["AnnualIncome"] = df["AnnualIncome"].astype(float)

# %%
df["Balance"] = df["Balance"].astype(float)

# %%
df["Target "] = df["Target "].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    1020 non-null   int64
#  1   Age           1020 non-null   int64
#  2   AnnualIncome  967 non-null    float64
#  3   Spending      1020 non-null   int64
#  4   CreditScore   1020 non-null   int64
#  5   Balance       969 non-null    float64
#  6   Tenure        1020 non-null   int64
#  7   Geography     969 non-null    object
#  8   Gender        968 non-null    object
#  9   Segment       969 non-null    object
#  10  Target        1020 non-null   object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 87.8+ KB

# %% [markdown]
# #### Challenge 7 – Customer Analytics
# #### Create a new DataFrame that
# #### • removes Segment
# #### • removes Geography
# #### • removes duplicate rows
# #### Display
# #### • first 10 rows
# #### • dataset information
# #### • statistical summary

# %%
new_df = df.drop(["Segment", "Geography"], axis=1)

new_df = new_df.drop_duplicates()

# %%
new_df.head(10)
# Out:
#    CustomerID  Age  AnnualIncome  Spending  CreditScore    Balance  Tenure  \
# 0       10001   58       49184.0      2139          581        NaN       2
# 1       10002   65      162964.0      6197          732    6356.54       1
# 2       10003   56       26956.0     37281          503  143203.92       8
# 3       10004   55       92926.0       925          463  139627.88       5
# 4       10005   66      108236.0      7198          394   75985.46       5
# 5       10006   69       31390.0     48323          770  107245.62       6
# 6       10007   58      182141.0     24200          891   38457.72       1
# 7       10008   67       95861.0      5729          538  173296.73       6
# 8       10009   41       62638.0     24760          663   41901.41       4
# 9       10010   22      179680.0     42113          475  106827.98       3
#
#    Gender Target
# 0    Male   Stay
# 1    Male  Churn
# 2    Male   Stay
# 3    Male  Churn
# 4   Other  Churn
# 5   Other   Stay
# ...

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    1000 non-null   int64
#  1   Age           1000 non-null   int64
#  2   AnnualIncome  950 non-null    float64
#  3   Spending      1000 non-null   int64
#  4   CreditScore   1000 non-null   int64
#  5   Balance       950 non-null    float64
#  6   Tenure        1000 non-null   int64
#  7   Gender        950 non-null    object
#  8   Target        1000 non-null   object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 78.1+ KB

# %%
new_df.describe()
# Out:
#          CustomerID          Age   AnnualIncome      Spending  CreditScore  \
# count   1000.000000  1000.000000     950.000000   1000.000000  1000.000000
# mean   10500.500000    44.202000  112458.303158  25285.558000   603.088000
# std      288.819436    15.130834   52409.868404  14211.735656   176.605486
# min    10001.000000    18.000000   20227.000000    537.000000   300.000000
# 25%    10250.750000    31.000000   65922.500000  13213.000000   441.000000
# 50%    10500.500000    44.000000  112347.500000  24901.000000   606.500000
# 75%    10750.250000    57.000000  157973.000000  37960.250000   758.250000
# max    11000.000000    70.000000  199967.000000  49995.000000   900.000000
#
#              Balance       Tenure
# count     950.000000  1000.000000
# mean    97557.565779     5.241000
# std     55845.536430     3.179155
# min       547.600000     0.000000
# 25%     50003.880000     2.000000
# 50%     95174.625000     5.000000
# 75%    144198.130000     8.000000
# ...

# %% [markdown]
# #### Challenge 8 – ML Dataset Preparation
# #### Prepare a machine learning dataset.
# #### Perform
# #### • Remove duplicates
# #### • Remove CustomerID
# #### • Remove Segment
# #### • Fill missing values
# #### • Rename Target to Output
# #### Finally
# #### Display
# #### head()
# #### info()
# #### describe()
# #### value_counts(Output)

# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\rohit\\Downloads\\Task_dataset - Task_dataset.csv")

df
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0          10001  58.0       49184.0      2139          581        NaN
# 1          10002  65.0      162964.0      6197          732    6356.54
# 2          10003  56.0       26956.0     37281          503  143203.92
# 3          10004  55.0       92926.0       925          463  139627.88
# 4          10005  66.0      108236.0      7198          394   75985.46
# ...          ...   ...           ...       ...          ...        ...
# 1015       10450  43.0      173620.0      7121          644   60353.03
# 1016       10753  25.0       54490.0     13794          303  124512.07
# 1017       10810  49.0       82062.0     47170          813   53850.09
# 1018       10267  38.0           NaN     10424          722  138100.05
# 1019       10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target
# 0          2    France    Male        SME   Stay
# ...

# %%
df.drop_duplicates(inplace =True)

# %%
df = df.drop(["CustomerID", "Segment"], axis=1)

# %%
df["Age"] = df["Age"].fillna(df["Age"].median())

# %%
df["AnnualIncome"] = df["AnnualIncome"].fillna(df["AnnualIncome"].median())

# %%
df["Balance"] = df["Balance"].fillna(df["Balance"].mean())

# %%
df = df.rename(columns={"Target": "Output"})

# %%
df.head()
# Out:
#     Age  AnnualIncome  Spending  CreditScore        Balance  Tenure Geography  \
# 0  58.0       49184.0      2139          581   97557.565779       2    France
# 1  65.0      162964.0      6197          732    6356.540000       1       USA
# 2  56.0       26956.0     37281          503  143203.920000       8    Canada
# 3  55.0       92926.0       925          463  139627.880000       5       NaN
# 4  66.0      108236.0      7198          394   75985.460000       5        UK
#
#   Gender Output
# 0   Male   Stay
# 1   Male  Churn
# 2   Male   Stay
# 3   Male  Churn
# 4  Other  Churn

# %%
df.describe()
# Out:
#                Age   AnnualIncome      Spending  CreditScore        Balance  \
# count  1000.000000    1000.000000   1000.000000  1000.000000    1000.000000
# mean     44.202000  112452.763000  25285.558000   603.088000   97557.565779
# std      15.130834   51081.480963  14211.735656   176.605486   54430.062006
# min      18.000000   20227.000000    537.000000   300.000000     547.600000
# 25%      31.000000   68437.250000  13213.000000   441.000000   52074.240000
# 50%      44.000000  112347.500000  24901.000000   606.500000   97557.565779
# 75%      57.000000  155570.750000  37960.250000   758.250000  142297.910000
# max      70.000000  199967.000000  49995.000000   900.000000  199885.880000
#
#             Tenure
# count  1000.000000
# mean      5.241000
# std       3.179155
# min       0.000000
# 25%       2.000000
# 50%       5.000000
# 75%       8.000000
# max      10.000000

# %%
df.value_counts()
# Out:
# Age   AnnualIncome  Spending  CreditScore  Balance    Tenure  Geography  Gender  Output
# 18.0  21864.0       38378     835          23565.72   0       Canada     Other   Churn     1
# 50.0  123395.0      13243     802          63551.56   9       Germany    Male    Stay      1
# 52.0  88876.0       49456     898          85686.77   9       Canada     Female  Stay      1
#       102766.0      32391     607          50194.81   9       India      Female  Stay      1
#       106960.0      25655     443          158099.62  1       Germany    Other   Churn     1
#                                                                                           ..
# 37.0  28449.0       29973     569          69715.40   1       Canada     Male    Churn     1
#       29796.0       48393     890          76309.22   0       UK         Female  Churn     1
#       55947.0       25582     436          128315.23  10      USA        Male    Churn     1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Age           1000 non-null   float64
#  1   AnnualIncome  1000 non-null   float64
#  2   Spending      1000 non-null   int64
#  3   CreditScore   1000 non-null   int64
#  4   Balance       1000 non-null   float64
#  5   Tenure        1000 non-null   int64
#  6   Geography     950 non-null    object
#  7   Gender        950 non-null    object
#  8   Output        1000 non-null   object
# dtypes: float64(3), int64(3), object(3)
# memory usage: 78.1+ KB

# %% [markdown]
# #### Challenge 9 – Column Transformation
# #### Create these new columns
# #### NetWorth = Balance + AnnualIncome
# #### AgeAfterRetirement = Age + 20
# #### DoubleCreditScore = CreditScore * 2
# #### IncomePerMonth = AnnualIncome / 12
# #### Then
# #### Display first 15 rows.

# %%
df["NetWorth"] = df["Balance"] + df["AnnualIncome"]

# %%
df["AgeAfterRetirement"] = df["Age"] + 20

# %%
df["DoubleCreditScore"] = df["CreditScore"] * 2

# %%
df["IncomePerMonth"] = df["AnnualIncome"] / 12

# %%
df.head(15)
# Out:
#      Age  AnnualIncome  Spending  CreditScore        Balance  Tenure  \
# 0   58.0       49184.0      2139          581   97557.565779       2
# 1   65.0      162964.0      6197          732    6356.540000       1
# 2   56.0       26956.0     37281          503  143203.920000       8
# 3   55.0       92926.0       925          463  139627.880000       5
# 4   66.0      108236.0      7198          394   75985.460000       5
# 5   69.0       31390.0     48323          770  107245.620000       6
# 6   58.0      182141.0     24200          891   38457.720000       1
# 7   67.0       95861.0      5729          538  173296.730000       6
# 8   41.0       62638.0     24760          663   41901.410000       4
# 9   22.0      179680.0     42113          475  106827.980000       3
# 10  44.0      187772.0     45599          870   43923.030000       5
# 11  69.0      102694.0     26790          574   13237.720000       9
# 12  59.0      150870.0     26428          769   28574.320000       2
# ...

# %% [markdown]
# #### Challenge 10 – Company Report
# #### Display
# #### • first five rows
# #### • last five rows
# #### • ten random rows
# #### • dataset information
# #### • descriptive statistics
# #### Finally rename
# #### Target → Customer_Status

# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\rohit\\Downloads\\Task_dataset - Task_dataset.csv")

df
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0          10001  58.0       49184.0      2139          581        NaN
# 1          10002  65.0      162964.0      6197          732    6356.54
# 2          10003  56.0       26956.0     37281          503  143203.92
# 3          10004  55.0       92926.0       925          463  139627.88
# 4          10005  66.0      108236.0      7198          394   75985.46
# ...          ...   ...           ...       ...          ...        ...
# 1015       10450  43.0      173620.0      7121          644   60353.03
# 1016       10753  25.0       54490.0     13794          303  124512.07
# 1017       10810  49.0       82062.0     47170          813   53850.09
# 1018       10267  38.0           NaN     10424          722  138100.05
# 1019       10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target
# 0          2    France    Male        SME   Stay
# ...

# %%
df.head()
# Out:
#    CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  Tenure  \
# 0       10001  58.0       49184.0      2139          581        NaN       2
# 1       10002  65.0      162964.0      6197          732    6356.54       1
# 2       10003  56.0       26956.0     37281          503  143203.92       8
# 3       10004  55.0       92926.0       925          463  139627.88       5
# 4       10005  66.0      108236.0      7198          394   75985.46       5
#
#   Geography Gender    Segment Target
# 0    France   Male        SME   Stay
# 1       USA   Male        SME  Churn
# 2    Canada   Male  Corporate   Stay
# 3       NaN   Male     Retail  Churn
# 4        UK  Other  Corporate  Churn

# %%
df.tail()
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  \
# 1015       10450  43.0      173620.0      7121          644   60353.03
# 1016       10753  25.0       54490.0     13794          303  124512.07
# 1017       10810  49.0       82062.0     47170          813   53850.09
# 1018       10267  38.0           NaN     10424          722  138100.05
# 1019       10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target
# 1015       2       USA   Other  Corporate   Stay
# 1016       4     India     NaN  Corporate  Churn
# 1017       8   Germany  Female     Retail   Stay
# 1018       6   Germany   Other  Corporate   Stay
# 1019      10    Canada   Other        NaN  Churn

# %%
df.sample()
# Out:
#      CustomerID   Age  AnnualIncome  Spending  CreditScore  Balance  Tenure  \
# 178       10179  21.0       22015.0     13897          608      NaN       2
#
#     Geography  Gender    Segment Target
# 178        UK  Female  Corporate   Stay

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    1020 non-null   int64
#  1   Age           970 non-null    float64
#  2   AnnualIncome  967 non-null    float64
#  3   Spending      1020 non-null   int64
#  4   CreditScore   1020 non-null   int64
#  5   Balance       969 non-null    float64
#  6   Tenure        1020 non-null   int64
#  7   Geography     969 non-null    object
#  8   Gender        968 non-null    object
#  9   Segment       969 non-null    object
#  10  Target        1020 non-null   object
# dtypes: float64(3), int64(4), object(4)
# memory usage: 87.8+ KB

# %%
df.describe()
# Out:
#          CustomerID         Age   AnnualIncome      Spending  CreditScore  \
# count   1020.000000  970.000000     967.000000   1020.000000  1020.000000
# mean   10501.599020   44.249485  112505.928645  25232.615686   602.659804
# std      288.022115   15.521935   52303.362541  14219.393105   176.560690
# min    10001.000000   18.000000   20227.000000    537.000000   300.000000
# 25%    10252.750000   30.250000   66149.000000  13134.750000   440.750000
# 50%    10502.500000   44.000000  112358.000000  24798.000000   607.000000
# 75%    10752.250000   58.000000  158000.500000  37956.000000   757.250000
# max    11000.000000   70.000000  199967.000000  49995.000000   900.000000
#
#              Balance       Tenure
# count     969.000000  1020.000000
# mean    97523.535666     5.261765
# std     55796.562543     3.185330
# min       547.600000     0.000000
# 25%     50077.860000     2.000000
# 50%     95100.060000     5.000000
# 75%    143947.810000     8.000000
# ...

# %%
df.rename(columns = {"Target":" Customer_Status"},inplace=True)
df
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0          10001  58.0       49184.0      2139          581        NaN
# 1          10002  65.0      162964.0      6197          732    6356.54
# 2          10003  56.0       26956.0     37281          503  143203.92
# 3          10004  55.0       92926.0       925          463  139627.88
# 4          10005  66.0      108236.0      7198          394   75985.46
# ...          ...   ...           ...       ...          ...        ...
# 1015       10450  43.0      173620.0      7121          644   60353.03
# 1016       10753  25.0       54490.0     13794          303  124512.07
# 1017       10810  49.0       82062.0     47170          813   53850.09
# 1018       10267  38.0           NaN     10424          722  138100.05
# 1019       10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment  Customer_Status
# ...

# %% [markdown]
# #### Challenge 11 – Missing Value Report
# #### Create a report showing
# #### • Total missing values
# #### • Numerical columns
# #### • Mean of Balance
# #### • Median of Age
# #### • Fill missing values
# #### • Display information again

# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\rohit\\Downloads\\Task_dataset - Task_dataset.csv")

df
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0          10001  58.0       49184.0      2139          581        NaN
# 1          10002  65.0      162964.0      6197          732    6356.54
# 2          10003  56.0       26956.0     37281          503  143203.92
# 3          10004  55.0       92926.0       925          463  139627.88
# 4          10005  66.0      108236.0      7198          394   75985.46
# ...          ...   ...           ...       ...          ...        ...
# 1015       10450  43.0      173620.0      7121          644   60353.03
# 1016       10753  25.0       54490.0     13794          303  124512.07
# 1017       10810  49.0       82062.0     47170          813   53850.09
# 1018       10267  38.0           NaN     10424          722  138100.05
# 1019       10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target
# 0          2    France    Male        SME   Stay
# ...

# %%
df.isnull().sum()
# Out:
# CustomerID       0
# Age             50
# AnnualIncome    53
# Spending         0
# CreditScore      0
# Balance         51
# Tenure           0
# Geography       51
# Gender          52
# Segment         51
# Target           0
# dtype: int64

# %%
df.describe()
# Out:
#          CustomerID         Age   AnnualIncome      Spending  CreditScore  \
# count   1020.000000  970.000000     967.000000   1020.000000  1020.000000
# mean   10501.599020   44.249485  112505.928645  25232.615686   602.659804
# std      288.022115   15.521935   52303.362541  14219.393105   176.560690
# min    10001.000000   18.000000   20227.000000    537.000000   300.000000
# 25%    10252.750000   30.250000   66149.000000  13134.750000   440.750000
# 50%    10502.500000   44.000000  112358.000000  24798.000000   607.000000
# 75%    10752.250000   58.000000  158000.500000  37956.000000   757.250000
# max    11000.000000   70.000000  199967.000000  49995.000000   900.000000
#
#              Balance       Tenure
# count     969.000000  1020.000000
# mean    97523.535666     5.261765
# std     55796.562543     3.185330
# min       547.600000     0.000000
# 25%     50077.860000     2.000000
# 50%     95100.060000     5.000000
# 75%    143947.810000     8.000000
# ...

# %%
mean_balance = df["Balance"].mean()

mean_balance
# Out:
# np.float64(97523.53566563467)

# %%
median_age = df["Age"].median()
median_age
# Out:
# 44.0

# %%
df["Balance"].fillna(mean_balance, inplace=True)
df["Age"].fillna(median_age,inplace=True)

# %%
for col in df.select_dtypes(include='object').columns:
    df[col].fillna(df[col].mode()[0], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    1020 non-null   int64
#  1   Age           1020 non-null   float64
#  2   AnnualIncome  967 non-null    float64
#  3   Spending      1020 non-null   int64
#  4   CreditScore   1020 non-null   int64
#  5   Balance       1020 non-null   float64
#  6   Tenure        1020 non-null   int64
#  7   Geography     969 non-null    object
#  8   Gender        968 non-null    object
#  9   Segment       969 non-null    object
#  10  Target        1020 non-null   object
# dtypes: float64(3), int64(4), object(4)
# memory usage: 87.8+ KB

# %% [markdown]
# #### Challenge 12 – Customer Classification
# #### Count
# #### Stay
#
# #### Churn
# #### Then
# #### Rename
# #### Target → Customer_Class
# #### Convert it into string.

# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\rohit\\Downloads\\Task_dataset - Task_dataset.csv")

df["Target"].value_counts()

df = df.rename(columns={"Target": "Customer_Class"})

df["Customer_Class"] = df["Customer_Class"].astype(str)

df.head()
# Out:
#    CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  Tenure  \
# 0       10001  58.0       49184.0      2139          581        NaN       2
# 1       10002  65.0      162964.0      6197          732    6356.54       1
# 2       10003  56.0       26956.0     37281          503  143203.92       8
# 3       10004  55.0       92926.0       925          463  139627.88       5
# 4       10005  66.0      108236.0      7198          394   75985.46       5
#
#   Geography Gender    Segment Customer_Class
# 0    France   Male        SME           Stay
# 1       USA   Male        SME          Churn
# 2    Canada   Male  Corporate           Stay
# 3       NaN   Male     Retail          Churn
# 4        UK  Other  Corporate          Churn

# %% [markdown]
# #### Challenge 13 – Sales Department
# #### Rename
# #### Balance → AccountBalance
# #### AnnualIncome → Salary
# #### CreditScore → Score
# #### Add prefix
# #### Sales_
# #### Then
# #### Display
# #### sample(20)

# %%
df = df.rename(columns={
    "Balance": "AccountBalance",
    "AnnualIncome": "Salary",
    "CreditScore": "Score"
})

df = df.add_prefix("Sales_")

print(df.sample(20))
# Out:
#      Sales_CustomerID  Sales_Age  Sales_Salary  Sales_Spending  Sales_Score  \
# 590             10591       47.0           NaN           33950          392
# 722             10723       59.0       22184.0            4864          697
# 194             10195       57.0       61614.0           24348          681
# 311             10312       61.0      178589.0           40013          340
# 718             10719       39.0       49170.0           20496          760
# 443             10444       66.0       77517.0           38228          697
# 747             10748       29.0      138929.0           39186          506
# 575             10576       19.0      144253.0           10744          846
# 872             10873        NaN       93182.0            1450          738
# 752             10753       25.0       54490.0           13794          303
# 877             10878       47.0      169521.0           49474          897
# ...

# %% [markdown]
# #### Challenge 14 – Interview Challenge
# #### Without creating another DataFrame,
# #### perform
# #### • remove duplicates
# #### • rename Target
# #### • fill missing values
# ####  • convert Balance to float
# #### • display summary

# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\rohit\\Downloads\\Task_dataset - Task_dataset.csv")

df.drop_duplicates(inplace=True)

df.rename(columns={"Target": "Customer_Class"}, inplace=True)

df["Balance"] = df["Balance"].fillna(df["Balance"].mean())

df["Balance"] = df["Balance"].astype(float)

df.describe()
# Out:
#          CustomerID         Age   AnnualIncome      Spending  CreditScore  \
# count   1000.000000  950.000000     950.000000   1000.000000  1000.000000
# mean   10500.500000   44.212632  112458.303158  25285.558000   603.088000
# std      288.819436   15.524244   52409.868404  14211.735656   176.605486
# min    10001.000000   18.000000   20227.000000    537.000000   300.000000
# 25%    10250.750000   30.000000   65922.500000  13213.000000   441.000000
# 50%    10500.500000   44.000000  112347.500000  24901.000000   606.500000
# 75%    10750.250000   58.000000  157973.000000  37960.250000   758.250000
# max    11000.000000   70.000000  199967.000000  49995.000000   900.000000
#
#              Balance       Tenure
# count    1000.000000  1000.000000
# mean    97557.565779     5.241000
# std     54430.062006     3.179155
# min       547.600000     0.000000
# 25%     52074.240000     2.000000
# 50%     97557.565779     5.000000
# 75%    142297.910000     8.000000
# ...

# %% [markdown]
# #### Challenge 15 – Data Engineer Task
# #### Load the dataset.
# #### Create another DataFrame containing only numeric columns.
# #### Drop
# #### CustomerID
# #### Target
# #### Display summary.

# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\rohit\\Downloads\\Task_dataset - Task_dataset.csv")

numeric_df = df.select_dtypes(include="number")

numeric_df = numeric_df.drop(columns=["CustomerID", "Target"], errors="ignore")

numeric_df.describe()
# Out:
#               Age   AnnualIncome      Spending  CreditScore        Balance  \
# count  970.000000     967.000000   1020.000000  1020.000000     969.000000
# mean    44.249485  112505.928645  25232.615686   602.659804   97523.535666
# std     15.521935   52303.362541  14219.393105   176.560690   55796.562543
# min     18.000000   20227.000000    537.000000   300.000000     547.600000
# 25%     30.250000   66149.000000  13134.750000   440.750000   50077.860000
# 50%     44.000000  112358.000000  24798.000000   607.000000   95100.060000
# 75%     58.000000  158000.500000  37956.000000   757.250000  143947.810000
# max     70.000000  199967.000000  49995.000000   900.000000  199885.880000
#
#             Tenure
# count  1020.000000
# mean      5.261765
# std       3.185330
# min       0.000000
# 25%       2.000000
# 50%       5.000000
# 75%       8.000000
# max      10.000000
