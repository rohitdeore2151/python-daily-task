# %% [markdown]
# ## Basic Exception Handling (1-10)

# %% [markdown]
# #### 1. Write a program that takes two numbers and performs division. Handle the ZeroDivisionError.

# %%
try:
    a = 5
    b = 0 
    c = a/b

except ZeroDivisionError:
    print("Zero Not Division")
# Out:
# Zero Not Division

# %% [markdown]
# #### 2. Take a number from user and convert it to integer. Handle ValueError if user enters a string.

# %%
try:
    a = int(input())
    print(a)

except ValueError:
    print("Error : Value Error Show")
# Out:
#  a
# Error : Value Error Show

# %% [markdown]
# #### 3. Access an element from a list using index. Handle IndexError.

# %%
try:
    a = [1,2,3,4]
    print(a[40])

except IndexError:
    print("Error : Element out of range in list")
# Out:
# Error : Element out of range in list

# %% [markdown]
# #### 4. Try to open a file that does not exist. Handle FileNotFoundError.

# %%
try:

# %% [markdown]
# #### 5. Create a dictionary and access a key that does not exist. Handle KeyError.

# %%
try:
    dics = {"Rohit":22,"santosh":33}
    print(dics["Yash"])

except KeyError:
    print("Error : key that does not exist")
# Out:
# Error : key that does not exist

# %%
#### 6. Write a program using try-except to handle multiple exceptions (ValueError and ZeroDivisionError).

try:
    a = int(input())
    b = int(input())
    c = a / b

except ValueError:
    print("Error: Please enter valid integer numbers.")

except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")
# Out:
#  abc
# Error: Please enter valid integer numbers.

# %% [markdown]
# #### 7. Demonstrate the use of else block with try-except.

# %%
try:
    a =  int(input())
    b =  int(input())
    c = a / b

except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")

else:
    print("Division successful.")
    print("Result =", c)
# Out:
#  5
#  5
# Division successful.
# Result = 1.0

# %% [markdown]
# #### 8. Demonstrate the use of finally block with an example.

# %%
try:
    a = int(input())
    b =  int(input())
    c = a / b

except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")

finally:
    print("Program execution completed.")
# Out:
#  4
#  6
# Program execution completed.

# %% [markdown]
# ####  9. Take age as input. Raise an exception if age is negative.

# %%
try:
    age = int(input("Enter your age: "))

    if age < 0:
        raise ValueError("Age cannot be negative.")

    print("Your age is:", age)

except ValueError as e:
    print("Exception:", e)
# Out:
# Enter your age:  -9
# Exception: Age cannot be negative.

# %% [markdown]
# #### 10. Write a program that handles TypeError when adding string and integer.

# %%
try:
    a = "Hello"
    b = 10

    c = a + b   
    print(c)

except TypeError as e:
    print("TypeError:", e)
# Out:
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ## Multiple Exceptions & Specific Handling (11-18)

# %% [markdown]
# #### 11. Handle ZeroDivisionError and ValueError in the same program using multiple except blocks.

# %%
try:
    a = int(input())
    b = int(input())
    c = a / b
    print("Result:", c)

except ValueError:
    print("Error: Please enter valid integers.")

except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")
# Out:
#  4
#  jj
# Error: Please enter valid integers.

# %% [markdown]
# #### 12. Use a single except block to handle any exception and print the error message.

# %%
try: 
      a = int(input())
      b = int(input())
      c = a / b
      print("Result:", c)

except Exception as e:
    print("Error:", e)
# Out:
#  5
#  0
# Error: division by zero

# %% [markdown]
# #### 13. Demonstrate nested try-except blocks.

# %%
try:
    a = int(input())

    try:
        b = int(input())
        c = a/b
    except ZeroDivisionError:
        print("Error : Division by zero is not allowed")

    else:
        print(c)

except ValueError:
    print("Error : Please Inter Valid Integer")
# Out:
#  aa
# Error : Please Inter Valid Integer

# %% [markdown]
# #### 14. Write a program that handles IndexError and KeyError separately.

# %%
try:
    my_list = [10, 20, 30]
    print("List element:", my_list[5])   # Causes IndexError

except IndexError:
    print("Error: List index is out of range.")

try:
    my_dict = {"name": "Alice", "age": 25}
    print("Dictionary value:", my_dict["city"])   # Causes KeyError

except KeyError:
    print("Error: Key not found in the dictionary.")
# Out:
# Error: List index is out of range.
# Error: Key not found in the dictionary.

# %% [markdown]
# #### 15. Take a list and a dictionary. Perform operations and handle possible exceptions.

# %%
try:
    numbers = [10, 20, 30]
    index = int(input("Enter list index: "))
    print("List element:", numbers[index])

except IndexError:
    print("Error: List index is out of range.")

except ValueError:
    print("Error: Please enter a valid integer index.")


try:
    student = {"name": "Rohit", "age": 20}
    key = input("Enter dictionary key: ")
    print("Dictionary value:", student[key])

except KeyError:
    print("Error: Key does not exist in the dictionary.")
# Out:
# Enter list index:  50
# Error: List index is out of range.
# Enter dictionary key:  yash
# Error: Key does not exist in the dictionary.

# %% [markdown]
# #### 16. Create a program that catches AttributeError when calling a non-existing method.

# %%
try:
    text = "Hello"
    
    text.append("World")

except AttributeError as e:
    print("AttributeError:", e)
# Out:
# AttributeError: 'str' object has no attribute 'append'

# %% [markdown]
# #### 17. Handle NameError when using a variable that is not defined.

# %%
try:
    Variable = "Rohit"
    print(variable)

except NameError:
    print("Error : Variable Not Difind")
# Out:
# Error : Variable Not Difind

# %% [markdown]
# #### 18. Write a program using try-except-else-finally all together.

# %%
try:
    a = int(input("Enter The Value"))
    if a % 2 == 0:
        print("Even Value")

    else:
        print("Odd Value")

except Exception as e:
    print(e)

else:
    print(a)

finally:
    print("Program Executed Successfully")
# Out:
# Enter The Value 4
# Even Value
# 4
# Program Executed Successfully

# %% [markdown]
# #### Raising Exceptions & Custom Exceptions (19-25)

# %% [markdown]
# #### 19. Write a function that takes age and raises ValueError if age is less than 18.

# %%
def check_age(age):
    if age < 18:
        raise ValueError("Error : Age is less than 18.")
    print("Eligible")

try:
    a = int(input("Enter The Age: "))
    check_age(a)

except ValueError as e:
    print("Error:", e)
# Out:
# Enter The Age:  17
# Error: Error : Age is less than 18.

# %% [markdown]
# #### 20. Create a custom exception called NegativeNumberError and raise it when user enters a  negative number.

# %%
class NegativeNumberError(Exception):
    pass


try:
    num = int(input("Enter a number: "))

    if num < 0:
        raise NegativeNumberError("Negative numbers are not allowed.")

    print("Entered number:", num)

except NegativeNumberError as e:
    print("Error:", e)

except ValueError:
    print("Error: Please enter a valid integer.")
# Out:
# Enter a number:  -5
# Error: Negative numbers are not allowed.

# %% [markdown]
# #### 21. Create a custom exception InsufficientBalanceError for a banking program.

# %%
class InsufficientBalanceError(Exception):
    pass

try:
    bank = int(input("Enter the Balance"))

    if bank <= 0:
        raise InsufficientBalanceError("Your Balance Are Insuficient")

    print("Balance Are Sufficient:",bank)

except InsufficientBalanceError as e:
    print("Error:",e)

except ValueError:
    print("Error:Please Enter A Valid Integer.")
# Out:
# Enter the Balance -55
# Error: Your Balance Are Insuficient

# %% [markdown]
# #### 22. Write a program that raises TypeError manually if the input is not a string.

# %%
class TypeError(Exception):
    pass
    
try:
    value = input("Enter a string: ")
    if not isinstance(value, str):
        raise TypeError("Input is not a string.")

    print("You entered:", value)

except TypeError as e:
    print("Error:", e)
# Out:
# Enter a string:  55
# You entered: 55

# %% [markdown]
# #### 23. Create a function that checks password length and raises a custom exception if length is less than 8.

# %%
class PasswordLengthError(Exception):
    pass


def check_password(password):
    if len(password) < 8:
        raise PasswordLengthError("Password must be at least 8 characters long.")
    else:
        print("Password is valid.")


try:
    pwd = input("Enter your password: ")
    check_password(pwd)

except PasswordLengthError as e:
    print("Error:", e)
# Out:
# Enter your password:  22554466
# Password is valid.

# %% [markdown]
# #### 24. Demonstrate how to raise an exception with a custom error message.

# %%
try:
    num = int(input("Enter a positive number: "))

    if num < 0:
        raise Exception("Custom Error: Negative numbers are not allowed.")

    print("You entered:", num)

except Exception as e:
    print(e)
# Out:
# Enter a positive number:  -55
# Custom Error: Negative numbers are not allowed.

# %% [markdown]
# #### 25. Write a program that uses raise to force an exception and handles it.

# %%
try:
    age = int(input("Enter your age: "))

    if age < 18:
        raise ValueError("You must be at least 18 years old.")

    print("Access granted.")

except ValueError as e:
    print("Exception caught:", e)
# Out:
# Enter your age:  17
# Exception caught: You must be at least 18 years old.

# %% [markdown]
# ## Practical / Hard Questions (26-30)

# %% [markdown]
# #### 26. Create a simple calculator that handles ZeroDivisionError, ValueError and invalid operator.

# %%
try:
    a = float(input("Enter the first value: "))
    operator = input("Enter Operator (+,-,*,/): ")
    b = float(input("Enter the second value: "))

    if operator == "+":
        print("Result =", a + b)
    elif operator == "-":
        print("Result =", a - b)
    elif operator == "*":
        print("Result =", a * b)
    elif operator == "/":
        print("Result =", a / b)
    else:
        raise Exception("Invalid operator!")

except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")

except ValueError:
    print("Error: Please enter valid numeric values.")

except Exception as e:
    print("Error:", e)
# Out:
# Enter the first value:  55
# Enter Operator (+,-,*,/):  /
# Enter the second value:  0
# Error: Division by zero is not allowed.

# %% [markdown]
# #### 27. Write a program to read a file. Handle FileNotFoundError and PermissionError.

# %%
try:
    file = open("network.txt", "r")
    print(file.read())
    file.close()

except FileNotFoundError:
    print("Error: File not found.")

except PermissionError:
    print("Error: Permission denied.")
# Out:
# Error: File not found.
