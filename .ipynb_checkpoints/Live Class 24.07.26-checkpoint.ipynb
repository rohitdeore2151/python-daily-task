# %%
# Inheritance : inheritance menas a child class gets all the properties and method of a parent class automatically.

# simple meaning "child gets evrything from parent"

# real life :

# exaple:-
# fahter has -  house ,car ,money,skill
# son gets - evrything from father automatcally
# son adds - his own skils  nad struff on top

# types of inheritance:
# single 
# multi level
# multiple
# hierarchical
# hybride

# %% [markdown]
# #####  Multi level inheritance  problem :

# %%
# Grand Parent --parent -- chid

#grand Parent 
class Person:

    #contructor:
    def __init__(self,name ,age):
        self.__Name =name 
        self.__Age = age # private attribute

    # getter:
    def get_name(self):'
        return f;name Of Person :{self.__Name}"

    # getter:
    def get_age(self):'
        return f;name Of Person :{self.__Age}"

    #setter of age :
    def set_age(self,age):
        if 20<age 60:
            self.__Age = age
            print(f"Age is updated  :{self.__Age}")

        else :
            print("please enter the greter than between the 20 and 60")


    #method:
    def person_info_(self):
        return f"Name of Person:{self.__Name}/n age is  {self.__Age}"

    # parent class :
    class Employee(Person):

    #constructor:
    def __init__(self,name,age,salary,company)
    super().__init__(name,age)
    self.Employee_Salary = salary
    self.Company_name = company

    
    # getter:
    def get_name(self):'
        return f"Salary bf Employee :{self.Employee_Salary}"

    # getter:
    def get_age(self):'
        return f"Company name of Employee:{ self.Company_name}"

    # seteer
    def set_salary(self,sal):

        if sal < (20/100) * self.Employee_Salary:
            self.Employee_Salary += sal
            print(f"Salary Is  Updated : {sal}")

        else:
            print("Please Update The Salary less than of  current salary")

    def employee_info(self):
        print(f"Employee Salary :{__Employee_Salary}")
        print(f"Employee Copany Name : {__Company_name}")
        print(self.person_info())

class Team(Employee):
    def __init__(self,name,age,salary,company,team_size,bones)
    super().__init__(name,age,salary,company)
    self.Team_Size = team_size
    self.Bonus = bones

    # getter:
    def get_company(self):'
        return f"Team Size is :{self.Team_Size}"

    # getter:
    def get_salary(self):'
        return f"New Bonus:{self.Bonus}"

       # seteer
    def team_size(self,team_size):

        if bonus < (10/100) * self.Team_Size:
            self.__Team_Size += bonus
            print(f"New Bonus Updated : {bonus}")

        else:
            print("Please Give The Bonus :")

      # seteer
    def set_bonus(self,bonus):

        if bonus < (10/100) * self.Employee_bonus:
            self.__Employee_bonus += bonus
            print(f"New Bonus Updated : {bonus}")

        else:
            print("Please Give The Bonus :")
