# %%
# Hybride Inheritance:
# Mix of multiple + Multi-Level

# problem :
# create  hybride inheritance:
# person-private _name ,_Age

# accessors + mutators
# mutator set_age - age must be between 18 and 65

# pilot(person) - private  _license, _flight_hours

# accessors + Mutators
# mutator set_flight_hour

# %%
class Person:
    def __init__(self,name,age):
        self.__Name = name
        self.__Age = age

    def get_name(self):
        return self.__Name

    def get_age(self):
        return self.__Age

    def set_age(self,age):
        if  18 <age< 65:
            self.__age = age
            print(f"gae is Updated Succefully :{self.__age}")

        else:
            print("Please Enter The Valid Age 18 to 65")

    def Pilot(Person):
        def __init__(self,license,flight_hourse):
            self.__License = license
            self.__Flight_Hourse = flight_hourse
    
    def get_license(self):
        return self.__License

    def get_flight_hoourse(self):
        return self.__Flight_Hourse
        
        

class Engineer(Person):
    def __init__(self,field,project):
        self.__Field = field 
        self.__Project = project

     def get_field(self):
        return self.__Field

    def get_project(self):
        return elf.__Project

    def set_age(self,project):
        if  0 < :
            self.__age = age
            print(f"gae is Updated Succefully :{self.__age}")

        else:
            print("Please Enter The Valid Age 18 to 65")

# %%
# Polymorphism - 1.polymorphism means one thing-many forms,2.same methood name - behaviour deffferent

# types :

# Duck typing:

class CreditCard:
    def pay(self, amount):
        return f"Paying amount using Credit Card: {amount}"

class DebitCard:
    def pay(self, amount):
        return f"Paying amount using Debit Card: {amount}"

class UPI:
    def pay(self, amount):
        return f"Paying amount using UPI: {amount}"

# Common function
def make_payment(payment, amount):
    return payment.pay(amount)

# Function calls
print(make_payment(CreditCard(), 2000))
print(make_payment(DebitCard(), 2000))
print(make_payment(UPI(), 2000))
# Out:
# Paying amount using Credit Card: 2000
# Paying amount using Debit Card: 2000
# Paying amount using UPI: 2000

# %%
# make three class

# 1 . circle
# attribute :radius
#method :  draw,area,

# 2 . rectangle
# attribute :width,height
#method :  draw,area,

# 3 . tringle
# attribute :base,height
#method :  draw,area,

# %%
import math

# Circle Class
class Circle:
    def __init__(self, radius):
        self.radius = radius

    def draw(self):
        print("Drawing a Circle")

    def area(self):
        return math.pi * self.radius ** 2


# Rectangle Class
class Rectangle:
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def draw(self):
        print("Drawing a Rectangle")

    def area(self):
        return self.width * self.height


# Triangle Class
class Triangle:
    def __init__(self, base, height):
        self.base = base
        self.height = height

    def draw(self):
        print("Drawing a Triangle")

    def area(self):
        return 0.5 * self.base * self.height


# Creating Objects
c = Circle(7)
r = Rectangle(10, 5)
t = Triangle(8, 6)

# Calling Methods
c.draw()
print("Circle Area:", c.area())

r.draw()
print("Rectangle Area:", r.area())

t.draw()
print("Triangle Area:", t.area())
# Out:
# Drawing a Circle
# Circle Area: 153.93804002589985
# Drawing a Rectangle
# Rectangle Area: 50
# Drawing a Triangle
# Triangle Area: 24.0
