# %%
#1. Write a program to check if a number is positive or negative.

num = int(input("Enter a number: "))

if num >= 0:
    print("Positive number")
else:
    print("Negative number")
# Out:
# Enter a number:  5
# Positive number

# %%
#2. Take age as input. If age is greater than or equal to 18, print "You can vote".
age = int(input("Enter your age: "))

if age >= 18:
    print("You can vote")
else:
    print("You cannot vote")
# Out:
# Enter your age:  22
# You can vote

# %%
#3. Take two numbers and print the larger one using if-else.
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

if a > b:
    print("Larger number is:", a)
else:
    print("Larger number is:", b)
# Out:
# Enter first number:  5
# Enter second number:  8
# Larger number is: 8

# %%
#4. Check if a given number is even or odd.
num = int(input("Enter a number: "))

if num % 2 == 0:
    print("Even number")
else:
    print("Odd number")
# Out:
# Enter a number:  5
# Odd number

# %%
# 5. Take a character and check if it is 'A' or not.
ch = input("Enter a character: ")

if ch == 'A':
    print("Character is A")
else:
    print("Character is not A")
# Out:
# Enter a character:  6
# Character is not A

# %%
#6. Take marks and print "Pass" if marks >= 40, otherwise "Fail".

marks = int(input("Enter marks: "))

if marks >= 40:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter marks:  55
# Pass

# %%
#7. Check if a number is divisible by 5.

num = int(input("Enter a number: "))

if num % 5 == 0:
    print("Number is divisible by 5")
else:
    print("Number is not divisible by 5")
# Out:
# Enter a number:  5
# Number is divisible by 5

# %%
#8. Take a number and print whether it is positive, negative, or zero.

num = int(input("Enter a number: "))

if num > 0:
    print("Positive number")
elif num < 0:
    print("Negative number")
else:
    print("Zero")
# Out:
# Enter a number:  8
# Positive number

# %%
#9. Take three numbers and print the largest number using if-elif-else.

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a >= b and a >= c:
    print("Largest number is:", a)
elif b >= a and b >= c:
    print("Largest number is:", b)
else:
    print("Largest number is:", c)
# Out:
# Enter first number:  5
# Enter second number:  6
# Enter third number:  8
# Largest number is: 8

# %%
#10. Take a year and check if it is a leap year.

year = int(input("Enter a year: "))

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Enter a year:  8
# Leap Year

# %%
#11. Take a character and check if it is a vowel or consonant.

ch = input("Enter a character: ")

if ch.lower() in ['a', 'e', 'i', 'o', 'u']:
    print("Vowel")
else:
    print("Consonant")
# Out:
# Enter a character:  8
# Consonant

# %%
#12. Take salary as input.

# Salary > 50000 → "High"
# Salary > 30000 → "Medium"
# Otherwise → "Low"

salary = int(input("Enter salary: "))

if salary > 50000:
    print("High")
elif salary > 30000:
    print("Medium")
else:
    print("Low")
# Out:
# Enter salary:  5000
# Low

# %%
# 13. Take temperature in Celsius and print Hot, Warm, or Cold.

temp = int(input("Enter temperature in Celsius: "))

if temp > 30:
    print("Hot")
elif temp >= 20 and temp <= 30:
    print("Warm")
else:
    print("Cold")
# Out:
# Enter temperature in Celsius:  20
# Warm

# %%
# 14. Take username and password. If both are correct print "Login Successful", else print "Login Failed".

username = input("Enter username: ")
password = input("Enter password: ")

if username == "admin" and password == "1234":
    print("Login Successful")
else:
    print("Login Failed")
# Out:
# Enter username:  admin
# Enter password:  1234
# Login Successful

# %%
#15. Take three sides of a triangle. Check if they form a valid triangle. If yes, print Equilateral, Isosceles, or Scalene.

a = int(input("Enter first side: "))
b = int(input("Enter second side: "))
c = int(input("Enter third side: "))

if (a + b > c) and (a + c > b) and (b + c > a):
    print("Valid Triangle")

    if a == b == c:
        print("Equilateral Triangle")
    elif a == b or b == c or a == c:
        print("Isosceles Triangle")
    else:
        print("Scalene Triangle")
else:
    print("Invalid Triangle")
# Out:
# Enter first side:  55
# Enter second side:  88
# Enter third side:  99
# Valid Triangle
# Scalene Triangle
