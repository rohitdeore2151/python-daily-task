# %% [markdown]
# ## Easy Level

# %%
# 1. Create a list named students with 5 student names and print it.

lists = ["Rohit","Yash","prashant","sagar","swaraj"]
print(lists)
# Out:
# ('Rohit', 'Yash', 'prashant', 'sagar', 'swaraj')

# %%
# 2. Create a list numbers = [10, 20, 30, 40, 50] and print its type and length using len().

lists = [10,20,30,40,50,]
len(lists)
# Out:
# 5

# %%
# 3. Create an empty list and append 3 numbers into it using append().

lists = [25,29,40]
lists.append(3)
print(lists)
# Out:
# [25, 29, 40, 3]

# %%
# 4. Given lst = [1, 2, 3], use extend() to add [4, 5, 6] to it.

lists = [1,2,3]
lists.extend([4,5,6])
print(lists)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# 5. Use insert() to add number 100 at index 2 in the list [10, 20, 30, 40].

lists = [10,20,30,40]
lists.insert(2,100)
print(lists)
# Out:
# [10, 20, 100, 30, 40]

# %%
# 6. Remove the element 50 from the list [10, 20, 50, 30, 50] using remove().

lists = [10,20,50,30,50]
lists.remove(50)
print(lists)
# Out:
# [10, 20, 30, 50]

# %%
# 7. Use pop() to remove the last element from lst = [5, 10, 15, 20] and print the list.

lists = [5,10,15,20]
lists.pop()
print(lists)
# Out:
# [5, 10, 15]

# %%
# 8. Clear all elements from the list data = [1, 2, 3, 4, 5] using clear().

lists = [1,2,3,4,5]
lists.clear()
print(lists)
# Out:
# []

# %% [markdown]
# ## Medium Level

# %%
# 9. Find the index of 25 in the list [10, 15, 25, 30, 40] using index().

lists = [10,15,25,30,40]
print(lists.index(25))
# Out:
# 2

# %%
# 10. Count how many times 7 appears in the list [7, 2, 7, 5, 7, 8] using count().

lists = [7,2,7,5,7,8]
print(lists.count(7))
# Out:
# 3

# %%
# 11. Sort the list [45, 12, 78, 23, 56] in ascending order using sort().

lists = [24,12,78,23,56]
lists.sort()
print(lists)
# Out:
# [12, 23, 24, 56, 78]

# %%
# 12. Sort the list [45, 12, 78, 23, 56] in descending order.

lists = [45,12,78,23,56]
lists.sort(reverse=True)

print(lists)
# Out:
# [78, 56, 45, 23, 12]

# %%
# 13. Reverse the list fruits = ["apple", "banana", "mango", "orange"] using reverse().

lists = ["apple","banana","mango","orange"]
lists.reverse()
print(lists)
# Out:
# ['orange', 'mango', 'banana', 'apple']

# %%
# 14. Create a copy of list original = [1, 2, 3, 4] using copy() and print both.

lists = [1,2,3,4]
lists.copy()

print(lists)
# Out:
# [1, 2, 3, 4]

# %%
# 15. Take a sentence from user (e.g. "I love Python programming") and convert it into a list of words using split().

sentence = input(" Enter The Sentence")
sentence = sentence.split()
print(sentence)
# Out:
#  Enter The Sentence I Love Python Programming
# ['I', 'Love', 'Python', 'Programming']

# %% [markdown]
# ## Hard / Mixed Level

# %%
# 16. Create a list of 5 numbers. Append 3 more numbers, then sort it in descending order.

lists = [22,29,30,55,66]
lists.append(57)
lists.append(79)
lists.append(80)

lists.sort(reverse=True)

print(lists)
# Out:
# [80, 79, 66, 57, 55, 30, 29, 22]

# %%
# 17. Create a list. Insert "Python" at index 0, then remove the last element using pop(), and print the length.

lists = [10,55,45,60,77]
lists.insert(0,"python")

lists.pop()

print(len(lists))
# Out:
# 5

# %%
# 18. Take 5 city names as input from user and store them in a list. Then print them in reverse order.

text =[]
for _ in range(5):
     cities = input("Enter the City")
     text.append(cities)
# Out:
# Enter the City dhule
# Enter the City nashik
# Enter the City pune
# Enter the City nandurbar
# Enter the City dondaicha

# %%
list(reversed(text))
# Out:
# ['dondaicha', 'nandurbar', 'pune', 'nashik', 'dhule ']

# %%
# 19. Given data = [10, 20, 30, 20, 40, 20], remove all occurrences of 20 (use loop or multiple remove).

data = [10, 20, 30, 20, 40, 20]
data.remove(20)
data.remove(20)
data.remove(20)

print(data)
# Out:
# [10, 30, 40]

# %%
# 20. Create a list of student marks. Sort it, find the highest and lowest mark using list methods, and print them.

lists = [35,40,55,60,90,99]
lists.sort()
print(lists[0])
print(lists[-1])
# Out:
# 35
# 99

# %%
# Out:
# Enter first number: 3
# Enter first number: 2
# Enter first number: 5
# 5 is gratter

# %%
print( "even" * (3 % 2 == 0) or "odd")
# Out:
# odd
