# %%
# 1. (Easy) Create a set with numbers {1, 2, 3, 2, 4, 1} and print it. What do you observe?

Set = {1,2,3,4,2,1}
Set
# Out:
# {1, 2, 3, 4}

# %%
# 2. (Easy) Create an empty set using correct syntax and add 3 numbers using add().

Set = set()
Set.add(1)
Set.add(2)
Set.add(3)
Set
# Out:
# {1, 2, 3}

# %%
# 3. (Easy) Given s = {10, 20, 30}, add multiple elements [40, 50, 60] using update().

# %%
set = {10,20,30}
set.update({40,50,60})
set
# Out:
# {10, 20, 30, 40, 50, 60}

# %%
# 4. (Medium) Remove element 20 from set s = {10, 20, 30, 40} using remove() and discard(). Show difference.

s = {10,20,30,40}
s.remove(20)
s
# Out:
# {10, 30, 40}

# %%
s.discard(20)
s
# Out:
# {10, 30, 40}

# %%
# 5. (Medium) Create two sets A = {1, 2, 3, 4} and B = {3, 4, 5, 6}. Print union, intersection, and difference.

A = {1, 2, 3, 4}

B = {3, 4, 5, 6}

A.union(B)
A
# Out:
# {1, 2, 3, 4}

# %%
# 6. (Medium) Check if 25 is present in set s = {10, 20, 30, 40} using in keyword.

sets = {10, 20, 30, 40}
print (25 in sets)
# Out:
# False

# %%
# 7. (Hard) Create a set from the list [1, 2, 2, 3, 4, 4, 5] and print its lengt

List = [1, 2, 2, 3, 4, 4, 5]
set1 = set(List)
print(len(set1))
# Out:
# 5

# %%
# 8. (Hard) Take 5 numbers as input from user, store them in a set, and print unique numbers only.

set1 =int(input ("Enter the Number:"))
set2 =int(input ("Enter the Number:"))
set3 =int(input ("Enter the Number:"))2
set4 =int(input ("Enter the Number:"))
set5 =int(input ("Enter the Number:"))

s = {set1,set2,set3,set4,set5}
s
# Out:
# Enter the Number: 1
# Enter the Number: 2
# Enter the Number: 3
# Enter the Number: 1
# Enter the Number: 5
# {1, 2, 3, 5}

# %%
# 9. (Hard) Given two sets A = {1, 2, 3} and B = {3, 4, 5}, print elements that are in A but not in B.

A = {1,2,3}

B = {3,4,5,}

A.difference(B)
# Out:
# {1, 2}

# %%
# 10. (Hard) Create a set and try to add a list [1,2,3] inside it. What happens?

set1 = {1,2,3,4,5,}
list1 = [1,2]

set1.add(list1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 6
#       3 set1 = {1,2,3,4,5,}
#       4 list1 = [1,2]
# ----> 6 set1.add(list1)
#
# TypeError: unhashable type: 'list'

# %%
# 11. (Easy) Take age as input. If age >= 18, print "You are eligible to vote".

age = int(input("Enter the age"))

if age >=18:
    print("eligible to vote")
# Out:
# Enter the age 22
# eligible to vote

# %%
# 12. (Easy) Take a number and check if it is positive, negative, or zero using if-elif-else.

number = int(input("Enter the Number"))

if number == 0:
    print("Zero")
elif number >0:
    print("positive")

elif number <0:
    print("Negative")
# Out:
# Enter the Number 0
# Zero

# %%
# 13. (Medium) Take two numbers and print the larger one using if-else.

number1 = int(input("Enter The Number"))
number2 = int(input("Enter The Number"))

if number1 > number2:
    print(number1,"is larger")
else:
    print(number2,"is larger")
# Out:
# Enter The Number 55
# Enter The Number 78
# 78 is larger

# %%
# 14. (Medium) Take a character and check if it is a vowel (a, e, i, o, u) using if statement.

char = input("Enter The Vowel:")

if char == "a" or char == "e" or char == "i" or char == "0" or char=="u":
    print("vowel")

else :
    print("consnant")
# Out:
# Enter The Vowel: y
# consnant

# %%
# 15. (Medium) Take marks and print grade: ≥90 → A, ≥80 → B, ≥70 → C, else →Fail.

Marks = int(input("Enter The Marks"))

if Marks >=90:
    print("Grade-A")
elif Marks >=80:
    print("Grade-B")
elif Marks >=70:
    print("Grade-C")
else :
    print("Fail")
# Out:
# Enter The Marks 50
# Fail

# %%
# 16. (Hard) Take three numbers and print the largest one using if-elif-else.

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a >= b and a >= c:
    print("Largest number is:", a)
elif b >= a and b >= c:
    print("Largest number is:", b)
else:
    print("Largest number is:", c)
# Out:
# Enter first number:  4
# Enter second number:  5
# Enter third number:  6
# Largest number is: 6

# %%
# 17. Take a number and check if it is even and greater than 50.

num = int(input("Enter a number: "))

if num % 2 == 0 and num > 50:
    print("The number is even and greater than 50.")
else:
    print("The number does not satisfy the condition.")
# Out:
# Enter a number:  56
# The number is even and greater than 50.

# %%
#18. Take username and password. If username == "admin" and password == "1234", print "Login Successful", else "Login Failed".
username = input("Enter username: ")
password = input("Enter password: ")

if username == "admin" and password == "1234":
    print("Login Successful")
else:
    print("Login Failed")
# Out:
# Enter username:  admin
# Enter password:  1234
# Login Successful

# %%
#19. Take a year as input and check if it is a leap year.A leap year is:
#Divisible by 4 and not divisible by 100, or
#Divisible by 400
year = int(input("Enter a year: "))

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Enter a year:  4
# Leap Year

# %%
# 20. Take three sides of a triangle and check if they can form a valid triangle.

# A triangle is valid if the sum of any two sides is greater than the third side.

a = float(input("Enter first side: "))
b = float(input("Enter second side: "))
c = float(input("Enter third side: "))

if (a + b > c) and (a + c > b) and (b + c > a):
    print("Valid Triangle")
else:
    print("Invalid Triangle")
# Out:
# Enter first side:  5
# Enter second side:  4
# Enter third side:  6
# Valid Triangle
