# %%
# 1. Take a number as input. If the number is positive, check whether it is even or odd and print the result.

Number = int(input("Enter the number"))

if Number >0:
    if Number %2==0:
        print("even")
    else:
        ("odd")
else:
    print("Number Is Zero ,Negative")
# Out:
# Enter the number 44
# even

# %%
# 2. Take age as input. If age is greater than or equal to 18, check if the person is a senior citizen (age >= 60) or adult.

Age = int (input("Enter The Age"))

if Age >=18:
    if Age >= 60:
        print("Senior Citigen")
    else:
        print("Adult")
else:
    print("Child")
# Out:
# Enter The Age 65
# Senior Citigen

# %%
# 3. Take a single character. If it is an alphabet, check whether it is uppercase or lowercase.

Character = str(input("Eneter The Any Character"))

if  Character.isalpha():
    if Character.isupper():
        print("uppeecase")
    else:
        print("lowercase")
else:
    ("Nothing")
# Out:
# Eneter The Any Character a
# lowercase

# %%
# 4. Take three numbers as input and print the largest number using nested if statements (without using max()).

A = 10
B = 20
C = 30

if A>B:
   if A>C:
      print(f"A is greater{C}")
   else:
       print(f"C is greater{A}")
else:
    print(f"B is greater{A}")
# Out:
# B is greater10

# %%
# 5. Take student marks. If marks >= 40 (Pass), then further check if marks >= 75 to print "Pass with Distinction".

Marks = int (input("Enter The Marks"))

if Marks >=40:
    if Marks >=75:
        print("Pass With distinction")
    else:
        print("Pass")
else:
    print("fail")
# Out:
# Enter The Marks 70
# Pass

# %%
# 6. Take a number. If it is divisible by 2, check if it is also divisible by 4.

Number = int (input("Enter The Number"))

if Number %2==0:
    if Number %4==0:
        print("Divisible By Both")
    else:
        print("Not Divisible By 2")
else:
    print("Not Divisible By Both")
# Out:
# Enter The Number 4
# Divisible By Both

# %%
# 7. Take username and password. If username is "admin", then check if the password is correct.

user_name = "Rohit@2005"
Password = 200005
user_id = input("Enter The Username")

if user_name == user_id:
    pas = int(input("Enter The Passsword"))  
    if Password == pas :
        print("Password Is Correct")
    else:
        print("Password Is Incorrect")
else:
    ("No Admin Username")
# Out:
# Enter The Username Rohit@2005
# Enter The Passsword 200005
# Password Is Correct

# %%
# 8. Take three sides of a triangle. First check if they form a valid triangle, then check if it is Equilateral, Isosceles, or Scalene.

a = float(input("Enter first side: "))
b = float(input("Enter second side: "))
c = float(input("Enter third side: "))

# Check if the triangle is valid
if (a + b > c) and (a + c > b) and (b + c > a):
    # Check type of triangle
    if a == b:
        if b == c:
            print("Equilateral Triangle")
        else:
            print("Isosceles Triangle")
    else:
        if a == c:
            print("Isosceles Triangle")
        else:
            if b == c:
                print("Isosceles Triangle")
            else:
                print("Scalene Triangle")
else:
    print("Invalid Triangle")
# Out:
# Enter first side:  44
# Enter second side:  4.4
# Enter third side:  40
# Scalene Triangle

# %%
# 9. Take salary and years of experience. If salary > 50000, check experience to decide "Manager" or "Senior Manager".

salary = int(input("Enter The Sallary"))
exprience = int(input("Enter Year Of Experience"))

if salary >50000:
    if exprience > 5:
        print(" Senior Manager")
    else:
        print("Manager")
else:
    print("Only Employe")
# Out:
# Enter The Sallary 500000
# Enter Year Of Experience 6
#  Senior Manager

# %%
# 10.Take a character. If it is a letter, check if it is vowel or consonant. If it is a digit, print "Digit". Else print "Special Character".

ch = input("Enter a character: ")

if ch.isalpha():
    if ch.lower() in "aeiou":
        print("Vowel")
    else:
        print("Consonant")
else:
    if ch.isdigit():
        print("Digit")
    else:
        print("Special Character")
# Out:
# Enter a character:  a
# Vowel

# %%
# 11.Take a year as input. Check if it is a leap year using nested conditions.

year = int(input("Enter The Year"))

if year % 4 == 0:
    if year % 100 == 0:
        if year % 400 == 0:
            print("leaf Year")
        else:
            ("Not  A Leaf Year")
    else:
        print("Leaf Year")
else:
    print("No Leeaf Year")
# Out:
# Enter The Year 2000
# leaf Year

# %%
## 12.Take temperature. If temperature > 30 print "Hot", if between 20-30 print "Warm", else "Cold" using nested if.

temp = float(input("Enter the temperature: "))

if temp > 30:
    print("Hot")
else:
    if temp >= 20:
        print("Warm")
    else:
        print("Cold")
# Out:
# Enter the temperature:  66
# Hot

# %%
# 13.Take three numbers. Check if all three are equal, or any two are equal using nested if.

a = int(input("Enter The Number"))
b = int(input("Enter The Number"))
c = int(input("Enter The Number"))

if a == b:
    if b == c:
        print("All three numbers are equal.")
    else:
        print("First and second numbers are equal.")
else:
    if a == c:
        print("First and third numbers are equal.")
    else:
        if b == c:
            print("Second and third numbers are equal.")
        else:
            print("No two numbers are equal.")
# Out:
# Enter The Number 45
# Enter The Number 45
# Enter The Number 55
# First and second numbers are equal.

# %%
# 14.Take a number. If it is positive and even, print "Positive Even Number".

number = int(input("Enter The Number"))

if number > 0:
    if number % 2 == 0:
        print("Positive Even Number")
# Out:
# Enter The Number 4
# Positive Even Number

# %%
# 15.Take marks of 5 subjects. If average >= 60, then check if all subjects are above 40 marks.

s1 = int(input("Enter marks of Subject 1: "))
s2 = int(input("Enter marks of Subject 2: "))
s3 = int(input("Enter marks of Subject 3: "))
s4 = int(input("Enter marks of Subject 4: "))
s5 = int(input("Enter marks of Subject 5: "))

average = (s1 + s2 + s3 + s4 + s5) / 5

if average >= 60:
    if s1 > 40 and s2 > 40 and s3 > 40 and s4 > 40 and s5 > 40:
        print("Average is 60 or above and all subjects are above 40.")
    else:
        print("Average is 60 or above, but not all subjects are above 40.")
else:
    print("Average is below 60.")
# Out:
# Enter marks of Subject 1:  50
# Enter marks of Subject 2:  88
# Enter marks of Subject 3:  77
# Enter marks of Subject 4:  44
# Enter marks of Subject 5:  35
# Average is below 60.

# %%
# 16.Take username, password, and age. If username and password are correct and
# age >= 18, print "Login Successful". Else if age < 18, print age restriction message.

username = input("Enter username: ")
password = input("Enter password: ")
age = int(input("Enter age: "))

if username == "Rohit222":
    if password == "@2004":
        if age >= 18:
            print("Login Successful")
        else:
            print("Access denied. You must be at least 18 years old.")
    else:
        print("Incorrect password.")
else:
    print("Incorrect username.")
# Out:
# Enter username:  Rohit222
# Enter password:  @2004
# Enter age:  22
# Login Successful

# %%
# 17.Take a number. Check if it is divisible by both 3 and 5 using nested if.

num = int(input("Enter a number: "))

if num % 3 == 0:
    if num % 5 == 0:
        print("The number is divisible by both 3 and 5.")
    else:
        print("The number is divisible by 3 but not by 5.")
else:
    print("The number is not divisible by both 3 and 5.")
# Out:
# Enter a number:  5
# The number is not divisible by both 3 and 5.

# %%
# 18.Take three sides of a triangle. Check if valid, then check if it is a right-angled triangle using Pythagoras theorem.

a = float(input("Enter first side: "))
b = float(input("Enter second side: "))
c = float(input("Enter third side: "))

# Check if the triangle is valid
if (a + b > c) and (a + c > b) and (b + c > a):
    # Find the largest side
    if a >= b and a >= c:
        if a * a == b * b + c * c:
            print("Valid triangle and it is a right-angled triangle.")
        else:
            print("Valid triangle but not a right-angled triangle.")
    elif b >= a and b >= c:
        if b * b == a * a + c * c:
            print("Valid triangle and it is a right-angled triangle.")
        else:
            print("Valid triangle but not a right-angled triangle.")
    else:
        if c * c == a * a + b * b:
            print("Valid triangle and it is a right-angled triangle.")
        else:
            print("Valid triangle but not a right-angled triangle.")
else:
    print("Invalid triangle.")
# Out:
# Enter first side:  5
# Enter second side:  5.5
# Enter third side:  6.5
# Valid triangle but not a right-angled triangle.

# %%
# 19.Take a grade (A, B, C, D, F) and print full description using if-elif-else (Excellent,  Good, Average, etc.).

grade = input("Enter your grade (A, B, C, D, F): ").upper()

if grade == "A":
    print("Excellent")
elif grade == "B":
    print("Good")
elif grade == "C":
    print("Average")
elif grade == "D":
    print("Poor")
elif grade == "F":
    print("Fail")
else:
    print("Invalid grade")
# Out:
# Enter your grade (A, B, C, D, F):  a
# Excellent

# %%
#20.Take income. If income > 1000000, check tax slab. If income between 500000- 1000000, different slab. Else print "Low Income".

income = float(input("Enter your income: "))

if income > 1000000:
    if income > 2000000:
        print("Tax Slab: 30%")
    else:
        print("Tax Slab: 20%")
elif income >= 500000:
    if income <= 750000:
        print("Tax Slab: 10%")
    else:
        print("Tax Slab: 15%")
else:
    print("Low Income")
# Out:
# Enter your income:  3000000
# Tax Slab: 30%

# %% [markdown]
# # Extra More Question (Optional)

# %%
# 1. (Hard) Take three sides of a triangle as input. First check if they can form a valid triangle 
# (sum of any two sides > third side). If valid, then further check and print
# whether the triangle is Equilateral, Isosceles, or Scalene.

A = float(input("Enter the number"))
B = float(input("Enter the number"))
C = float(input("Enter the number"))

if A + B > C and B + C > A and A + C > B :
    print("valid Tringle")
    if A == B and B == C :
        print("Equvalent Tringle")
    else :
        if A == B or B == C or A == C :
            print("Isosceles Tringle")
        else :
            if A != B and B != C and A != C :
                print("Isosceles Tringle")
            else :
                print("Scalene Tringgle")
        
else :
    print("Invalid Tringle")
# Out:
# Enter the number 44
# Enter the number 45
# Enter the number 55
# valid Tringle
# Isosceles Tringle

# %%
# 2. (Hard) Take a student's marks in 5 subjects. Calculate the average. If average >=60, 
# then check if all individual subjects are above 40. If yes, print "Pass with Good Performance",
# else print "Pass but Weak in some subjects". If average < 60, print "Fail".

eng = int(input("Enter The Number"))
bio = int(input("Enter The Number"))
chem = int(input("Enter The Number"))
math= int(input("Enter The Number"))
phy = int(input("Enter The Number"))

average = (eng+bio+chem+math+phy) / 5

if average >= 60
    if eng>40 and bio>40 and chem>40 and math>40 and phy>40 :
        print("Pass With Good Performance")
    else :
        print("Pass but Weak in some subjects")
else :
    print("Fail
